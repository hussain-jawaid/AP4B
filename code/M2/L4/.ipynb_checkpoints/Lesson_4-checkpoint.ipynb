# %% [markdown]
# # Lesson 4 - Customizing recipes with lists, dictionaries and AI

# %% [markdown]
# In the previous lesson, you went through how to use dictionaries to complete tasks by priority. In this lesson, you will see how you can use dictionaries to update LLM prompts and create food recipies that match your friends preferences, restrictions and cooking experience.

# %%
from helper_functions import print_llm_response, get_llm_response

# %% [markdown]
# ## Food preference dictionaries
#
# Dictionaries are a useful way to organize multiple variables associated with a single entity, like one of your friends. In the next dictionary, you store the food preferences and cooking experience for Tommy.

# %%
food_preferences_tommy = {
        "dietary_restrictions": "vegetarian",
        "favorite_ingredients": ["tofu", "olives"],
        "experience_level": "intermediate",
        "maximum_spice_level": 6
}

# %% [markdown]
# As you can see there, that dictionary has four keys, wich you can access using `".keys()"`:

# %%
print(food_preferences_tommy.keys())
# Out:
# dict_keys(['dietary_restrictions', 'favorite_ingredients', 'experience_level', 'maximum_spice_level'])

# %% [markdown]
# And it has values with different data types: lists, strings and integers.

# %%
print(food_preferences_tommy.values())
# Out:
# dict_values(['vegetarian', ['tofu', 'olives'], 'intermediate', 6])

# %% [markdown]
# Let's see how you can use these in a prompt to create recipes that take into account your friends dietary preferences.

# %% [markdown]
# ## Using keys and values within AI prompt

# %% [markdown]
# So here's a prompt that uses all the information in the dictionary to create a customized recipe

# %%
prompt = f"""Please suggest a recipe that tries to include 
the following ingredients: 
{food_preferences_tommy["favorite_ingredients"]}.
The recipe should adhere to the following dietary restrictions:
{food_preferences_tommy["dietary_restrictions"]}.
The difficulty of the recipe should be: 
{food_preferences_tommy["experience_level"]}
The maximum spice level on a scale of 10 should be: 
{food_preferences_tommy["maximum_spice_level"]} 
Provide a two sentence description.
"""

# %% [markdown]
# Run the cell below to print the prompt.

# %%
print(prompt)
# Out:
# Please suggest a recipe that tries to include
# the following ingredients:
# ['tofu', 'olives'].
# The recipe should adhere to the following dietary restrictions:
# vegetarian.
# The difficulty of the recipe should be:
# intermediate
# The maximum spice level on a scale of 10 should be:
# 6
# Provide a two sentence description.

# %% [markdown]
# Now, you can use that prompt with an LLM to suggest a recipe to fit Tommy's preferences:

# %%
print_llm_response(prompt)
# Out:
# ____________________________________________________________________________________________________
# Try a Mediterranean Tofu and Olive Stir-Fry: sauté firm tofu cubes with garlic, onions, bell peppers, and a mix of green and black olives, seasoned with smoked paprika and a touch of chili flakes for mild heat. This vegetarian dish balances savory and tangy flavors with a moderate spice level, perfect for an intermediate cook.
# ____________________________________________________________________________________________________

# %% [markdown]
# The model followed the instructions. Tommy will be delighted!

# %% [markdown]
# ## Refining the prompt with available ingredients

# %% [markdown]
# You can go a step further and consider the available ingredients at your house. To do so, let's use the following lists:

# %%
available_spices = ["cumin", "turmeric", "oregano", "paprika"]

# %% [markdown]
# You can add these directly to the prompt so that the LLM take those into consideration

# %%
prompt = f"""Please suggest a recipe that tries to include 
the following ingredients: 
{food_preferences_tommy["favorite_ingredients"]}.
The recipe should adhere to the following dietary restrictions:
{food_preferences_tommy["dietary_restrictions"]}.
The difficulty of the recipe should be: 
{food_preferences_tommy["experience_level"]}
The maximum spice level on a scale of 10 should be: 
{food_preferences_tommy["maximum_spice_level"]} 
Provide a two sentence description.

The recipe should not include spices outside of this list:
Spices: {available_spices}
"""
print(prompt)
# Out:
# Please suggest a recipe that tries to include
# the following ingredients:
# ['tofu', 'olives'].
# The recipe should adhere to the following dietary restrictions:
# vegetarian.
# The difficulty of the recipe should be:
# intermediate
# The maximum spice level on a scale of 10 should be:
# 6
# Provide a two sentence description.
#
# The recipe should not include spices outside of this list:
# Spices: ['cumin', 'turmeric', 'oregano', 'paprika']

# %% [markdown]
# Now, get the LLM response to that prompt and assign it to a variable:

# %%
recipe = get_llm_response(prompt)

# %% [markdown]
# And print the recipe that considers Tommy's restrictions as well as the available ingredients at your house.

# %%
print(recipe)
# Out:
# Try a Mediterranean Tofu and Olive Stir-fry: sauté cubed tofu with chopped olives, onions, and bell peppers, seasoned with cumin, oregano, and paprika for a flavorful, vegetarian dish with moderate spice. Serve over rice or couscous for a satisfying, intermediate-level meal.

# %% [markdown]
# Try changing the prompt to give you step-by-step instructions and try adding a key-value pair to the dictionary that indicates favorite cuisine.

# %%
food_preferences_tommy["cuisine"] = "Italian"

# %%
print(food_preferences_tommy)
# Out:
# {'dietary_restrictions': 'vegetarian', 'favorite_ingredients': ['tofu', 'olives'], 'experience_level': 'intermediate', 'maximum_spice_level': 6, 'cuisine': 'Italian'}

# %%
prompt = f"""Please suggest a recipe that tries to include 
the following ingredients: 
{food_preferences_tommy["favorite_ingredients"]}.
The recipe should adhere to the following dietary restrictions:
{food_preferences_tommy["dietary_restrictions"]}.
The difficulty of the recipe should be: 
{food_preferences_tommy["experience_level"]}
The maximum spice level on a scale of 10 should be: 
{food_preferences_tommy["maximum_spice_level"]} 
The cuisine should be:
{food_preferences_tommy["cuisine"]}
Provide me step-by-step instructions.

The recipe should not include spices outside of this list:
Spices: {available_spices}
"""
print(prompt)
# Out:
# Please suggest a recipe that tries to include
# the following ingredients:
# ['tofu', 'olives'].
# The recipe should adhere to the following dietary restrictions:
# vegetarian.
# The difficulty of the recipe should be:
# intermediate
# The maximum spice level on a scale of 10 should be:
# 6
# The cuisine should be:
# Italian
# Provide me step-by-step instructions.
#
# The recipe should not include spices outside of this list:
# Spices: ['cumin', 'turmeric', 'oregano', 'paprika']

# %%
print_llm_response(prompt)
# Out:
# ____________________________________________________________________________________________________
# **Italian Tofu and Olive Sauté**
#
# **Ingredients:**
# - 400g firm tofu, pressed and cubed
# - 1 cup mixed olives, pitted and sliced
# - 2 tbsp olive oil
# - 1 medium onion, finely chopped
# - 3 garlic cloves, minced
# - 1 tsp dried oregano
# - 1/2 tsp paprika (for mild heat, adjust to max 6/10)
# - Salt and black pepper to taste
# - 1 can (400g) diced tomatoes
# - Fresh basil leaves (optional, for garnish)
# - Cooked pasta or crusty bread, to serve
#
# **Instructions:**
#
# 1. **Prepare tofu:** Press tofu to remove excess water, then cut into 1-inch cubes.
#
# 2. **Sauté aromatics:** Heat olive oil in a large skillet over medium heat. Add chopped onion and cook until translucent, about 5 minutes. Add minced garlic and cook for 1 minute more.
#
# 3. **Cook tofu:** Add tofu cubes to the skillet. Cook, turning occasionally, until golden on all sides, about 8-10 minutes.
#
# 4. **Add spices:** Sprinkle oregano and paprika over tofu. Stir well to coat evenly.
#
# 5. **Add olives and tomatoes:** Stir in sliced olives and canned diced tomatoes with their juice. Simmer for 10-12 minutes, allowing flavors to meld and sauce to thicken slightly.
#
# 6. **Season:** Taste and add salt and black pepper as needed.
#
# 7. **Serve:** Garnish with fresh basil if desired. Serve hot over cooked pasta or with crusty bread.
#
# Enjoy your Italian-inspired vegetarian tofu and olive dish!
# ____________________________________________________________________________________________________

# %% [markdown]
# ## Looking ahead

# %% [markdown]
# Let's take another look at`food_preferences_tommy["dietary_restrictions"]`

# %%
print(food_preferences_tommy["dietary_restrictions"])
# Out:
# vegetarian

# %% [markdown]
# Here is a different way you could tell Python that Tommy is vegetarian:

# %%
food_preferences_tommy["is_vegetarian"] = True

# %%
print(food_preferences_tommy)
# Out:
# {'dietary_restrictions': 'vegetarian', 'favorite_ingredients': ['tofu', 'olives'], 'experience_level': 'intermediate', 'maximum_spice_level': 6, 'cuisine': 'Italian', 'is_vegetarian': True}

# %% [markdown]
# Go to next video to see what `True` and `False` are and how they work in Python

# %% [markdown]
# ## Extra practice

# %% [markdown]
# Please go through the exercises in the cells below if you want some extra practice for the topics you covered in this lesson.

# %%
# Update the following dictionary 
# with your own preferences 

### EDIT THE FOLLOWING CODE ###
my_food_preferences = {
        "dietary_restrictions": ["vegetarian"], #List with dietary restrictions
        "favorite_ingredients": ["Black Paper", "Salt"], #List with top three favorite ingredients
        "experience_level": "professional", #Experience level
        "maximum_spice_level": 7 #Spice level in a scale from 1 to 10
}
### --------------- ###

print(my_food_preferences)
# Out:
# {'dietary_restrictions': ['vegetarian'], 'favorite_ingredients': ['Black Paper', 'Salt'], 'experience_level': 'professional', 'maximum_spice_level': 7}

# %%
# Modify the following prompt, 
# without adding more than two sentences,
# so that the provided recipe includes detailed instructions.

### EDIT THE FOLLOWING CODE ###
#Hint: look at the last sentence in this prompt
prompt = f"""Please suggest a recipe that tries to include 
the following ingredients: 
{my_food_preferences["favorite_ingredients"]}.
The recipe should adhere to the following dietary restrictions:
{my_food_preferences["dietary_restrictions"]}.
The difficulty of the recipe should be: 
{my_food_preferences["experience_level"]}
The maximum spice level on a scale of 10 should be: 
{my_food_preferences["maximum_spice_level"]}
"""
### --------------- ###

print_llm_response(prompt)
# Out:
# ____________________________________________________________________________________________________
# Recipe: Black Pepper and Salt Crusted Grilled Tofu Steaks
#
# Ingredients:
# - 400g firm tofu, pressed and sliced into 1-inch thick steaks
# - 2 tbsp coarsely ground black pepper
# - 1 tbsp sea salt
# - 2 tbsp olive oil
# - 1 tsp smoked paprika (for mild spice, adjust to keep spice ≤7)
# - 1 tsp garlic powder
# - Fresh herbs (thyme or rosemary) for garnish
#
# Instructions:
# 1. In a small bowl, mix black pepper, salt, smoked paprika, and garlic powder.
# 2. Brush tofu steaks with olive oil on both sides.
# 3. Press the spice mixture evenly onto both sides of the tofu steaks.
# 4. Preheat grill or grill pan to medium-high heat.
# 5. Grill tofu steaks for 4-5 minutes per side until nicely charred and cooked through.
# 6. Garnish with fresh herbs and serve immediately.
#
# This recipe is vegetarian, uses black pepper and salt prominently, has a professional-level technique with grilling and spice crusting, and maintains a moderate spice level.
# ____________________________________________________________________________________________________
